# %% [markdown]
# # U-Net 모델 build

# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

print('슝=3')
# Out:
# 슝=3

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
  if is_train:    # 훈련용 데이터일 경우
    return Compose([
                    HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                    RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                        min_max_height=(300, 370),
                        w2h_ratio=370/1242,
                        height=224,
                        width=224,
                        p=0.5
                        ),
                    Resize(              # 입력이미지를 224X224로 resize
                        width=224,
                        height=224
                        )
                    ])
  return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %%
dir_path = os.getenv('HOME')+'/aiffel/semantic_segmentation/data/training'

# %%
augmentation_train = build_augmentation()
augmentation_test = build_augmentation(is_train=False)
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation_test(**image_data)
    processed = augmentation_train(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
  
plt.show()

# %%
class KittiGenerator(tf.keras.utils.Sequence):
  '''
  KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
  우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
  '''
  def __init__(self, 
               dir_path,
               batch_size=16,
               img_size=(224, 224, 3),
               output_size=(224, 224),
               is_train=True,
               augmentation=None):
    '''
    dir_path: dataset의 directory path입니다.
    batch_size: batch_size입니다.
    img_size: preprocess에 사용할 입력이미지의 크기입니다.
    output_size: ground_truth를 만들어주기 위한 크기입니다.
    is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
    augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
    '''
    self.dir_path = dir_path
    self.batch_size = batch_size
    self.is_train = is_train
    self.dir_path = dir_path
    self.augmentation = augmentation
    self.img_size = img_size
    self.output_size = output_size

    # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
    self.data = self.load_dataset()

  def load_dataset(self):
    # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
    # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
    input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
    label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
    input_images.sort()
    label_images.sort()
    assert len(input_images) == len(label_images)
    data = [ _ for _ in zip(input_images, label_images)]

    if self.is_train:
      return data[:-30]
    return data[-30:]
    
  def __len__(self):
    # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
    return math.ceil(len(self.data) / self.batch_size)

  def __getitem__(self, index):
    # 입력과 출력을 만듭니다.
    # 입력은 resize및 augmentation이 적용된 input image이고 
    # 출력은 semantic label입니다.
    batch_data = self.data[
                           index*self.batch_size:
                           (index + 1)*self.batch_size
                           ]
    inputs = np.zeros([self.batch_size, *self.img_size])
    outputs = np.zeros([self.batch_size, *self.output_size])
        
    for i, data in enumerate(batch_data):
      input_img_path, output_path = data
      _input = imread(input_img_path)
      _output = imread(output_path)
      _output = (_output==7).astype(np.uint8)*1
      data = {
          "image": _input,
          "mask": _output,
          }
      augmented = self.augmentation(**data)
      inputs[i] = augmented["image"]/255
      outputs[i] = augmented["mask"]
      return inputs, outputs

  def on_epoch_end(self):
    # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
    self.indexes = np.arange(len(self.data))
    if self.is_train == True :
      np.random.shuffle(self.indexes)
      return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %%
def build_model(input_shape=(224, 224, 3)):
    model = None
    # TODO: input_shape에 따라 U-Net을 만들어주세요
    # 이때 model은 fully convolutional해야 합니다.
    inputs = Input(input_shape)

    #Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)

    #Expanding Path
    drop5 = Dropout(0.5)(conv5)
    up6 = Conv2DTranspose(512, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(drop5)
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
    up7 = Conv2DTranspose(256, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv6)
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
    up8 = Conv2DTranspose(128, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv7)
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
    up9 = Conv2DTranspose(64, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv8)
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)
    return model

# %%
model = build_model()
model.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy')
model.fit(
     train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=200,
 )

model_path = os.getenv('HOME')+'/aiffel/semantic_segmentation/seg_model_unet_200.h5'
model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/200
# 11/11 [==============================] - 35s 561ms/step - loss: 0.6931 - val_loss: 0.6926
# Epoch 2/200
# 11/11 [==============================] - 6s 528ms/step - loss: 0.6924 - val_loss: 0.6921
# Epoch 3/200
# 11/11 [==============================] - 6s 530ms/step - loss: 0.6918 - val_loss: 0.6916
# Epoch 4/200
# 11/11 [==============================] - 6s 531ms/step - loss: 0.6913 - val_loss: 0.6910
# Epoch 5/200
# 11/11 [==============================] - 6s 532ms/step - loss: 0.6908 - val_loss: 0.6905
# Epoch 6/200
# 11/11 [==============================] - 6s 533ms/step - loss: 0.6903 - val_loss: 0.6900
# Epoch 7/200
# 11/11 [==============================] - 6s 537ms/step - loss: 0.6897 - val_loss: 0.6894
# Epoch 8/200
# 11/11 [==============================] - 6s 538ms/step - loss: 0.6892 - val_loss: 0.6889
# Epoch 9/200
# 11/11 [==============================] - 6s 543ms/step - loss: 0.6886 - val_loss: 0.6884
# Epoch 10/200
# 11/11 [==============================] - 6s 545ms/step - loss: 0.6881 - val_loss: 0.6879
# Epoch 11/200
# 11/11 [==============================] - 6s 546ms/step - loss: 0.6875 - val_loss: 0.6873
# Epoch 12/200
# 11/11 [==============================] - 6s 547ms/step - loss: 0.6870 - val_loss: 0.6868
# Epoch 13/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6865 - val_loss: 0.6863
# Epoch 14/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6860 - val_loss: 0.6857
# Epoch 15/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6854 - val_loss: 0.6852
# Epoch 16/200
# 11/11 [==============================] - 6s 556ms/step - loss: 0.6849 - val_loss: 0.6847
# Epoch 17/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6843 - val_loss: 0.6841
# Epoch 18/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6838 - val_loss: 0.6836
# Epoch 19/200
# 11/11 [==============================] - 6s 560ms/step - loss: 0.6833 - val_loss: 0.6831
# Epoch 20/200
# 11/11 [==============================] - 6s 562ms/step - loss: 0.6828 - val_loss: 0.6826
# Epoch 21/200
# 11/11 [==============================] - 6s 562ms/step - loss: 0.6823 - val_loss: 0.6821
# Epoch 22/200
# 11/11 [==============================] - 6s 562ms/step - loss: 0.6818 - val_loss: 0.6815
# Epoch 23/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6812 - val_loss: 0.6810
# Epoch 24/200
# 11/11 [==============================] - 6s 557ms/step - loss: 0.6807 - val_loss: 0.6805
# Epoch 25/200
# 11/11 [==============================] - 6s 557ms/step - loss: 0.6801 - val_loss: 0.6800
# Epoch 26/200
# 11/11 [==============================] - 6s 557ms/step - loss: 0.6797 - val_loss: 0.6794
# Epoch 27/200
# 11/11 [==============================] - 6s 556ms/step - loss: 0.6791 - val_loss: 0.6789
# Epoch 28/200
# 11/11 [==============================] - 6s 556ms/step - loss: 0.6785 - val_loss: 0.6784
# Epoch 29/200
# 11/11 [==============================] - 6s 557ms/step - loss: 0.6781 - val_loss: 0.6779
# Epoch 30/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6775 - val_loss: 0.6774
# Epoch 31/200
# 11/11 [==============================] - 6s 560ms/step - loss: 0.6770 - val_loss: 0.6768
# Epoch 32/200
# 11/11 [==============================] - 6s 559ms/step - loss: 0.6766 - val_loss: 0.6764
# Epoch 33/200
# 11/11 [==============================] - 6s 559ms/step - loss: 0.6760 - val_loss: 0.6759
# Epoch 34/200
# 11/11 [==============================] - 6s 559ms/step - loss: 0.6755 - val_loss: 0.6753
# Epoch 35/200
# 11/11 [==============================] - 6s 562ms/step - loss: 0.6749 - val_loss: 0.6748
# Epoch 36/200
# 11/11 [==============================] - 6s 560ms/step - loss: 0.6744 - val_loss: 0.6743
# Epoch 37/200
# 11/11 [==============================] - 6s 560ms/step - loss: 0.6740 - val_loss: 0.6738
# Epoch 38/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6733 - val_loss: 0.6733
# Epoch 39/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6729 - val_loss: 0.6727
# Epoch 40/200
# 11/11 [==============================] - 6s 557ms/step - loss: 0.6722 - val_loss: 0.6722
# Epoch 41/200
# 11/11 [==============================] - 6s 556ms/step - loss: 0.6719 - val_loss: 0.6717
# Epoch 42/200
# 11/11 [==============================] - 6s 559ms/step - loss: 0.6713 - val_loss: 0.6712
# Epoch 43/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6707 - val_loss: 0.6707
# Epoch 44/200
# 11/11 [==============================] - 6s 560ms/step - loss: 0.6701 - val_loss: 0.6702
# Epoch 45/200
# 11/11 [==============================] - 6s 559ms/step - loss: 0.6699 - val_loss: 0.6697
# Epoch 46/200
# 11/11 [==============================] - 6s 559ms/step - loss: 0.6694 - val_loss: 0.6691
# Epoch 47/200
# 11/11 [==============================] - 6s 560ms/step - loss: 0.6686 - val_loss: 0.6685
# Epoch 48/200
# 11/11 [==============================] - 6s 563ms/step - loss: 0.6698 - val_loss: 0.6682
# Epoch 49/200
# 11/11 [==============================] - 6s 558ms/step - loss: 0.6679 - val_loss: 0.6677
# Epoch 50/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6672 - val_loss: 0.6672
# Epoch 51/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6671 - val_loss: 0.6667
# Epoch 52/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6663 - val_loss: 0.6662
# Epoch 53/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6659 - val_loss: 0.6657
# Epoch 54/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6653 - val_loss: 0.6652
# Epoch 55/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6648 - val_loss: 0.6647
# Epoch 56/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6643 - val_loss: 0.6642
# Epoch 57/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6636 - val_loss: 0.6637
# Epoch 58/200
# 11/11 [==============================] - 6s 554ms/step - loss: 0.6631 - val_loss: 0.6632
# Epoch 59/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6627 - val_loss: 0.6627
# Epoch 60/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6622 - val_loss: 0.6621
# Epoch 61/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6616 - val_loss: 0.6616
# Epoch 62/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6613 - val_loss: 0.6611
# Epoch 63/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6608 - val_loss: 0.6606
# Epoch 64/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6601 - val_loss: 0.6601
# Epoch 65/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6596 - val_loss: 0.6596
# Epoch 66/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6592 - val_loss: 0.6591
# Epoch 67/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6586 - val_loss: 0.6586
# Epoch 68/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6580 - val_loss: 0.6581
# Epoch 69/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6576 - val_loss: 0.6576
# Epoch 70/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6571 - val_loss: 0.6571
# Epoch 71/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6567 - val_loss: 0.6566
# Epoch 72/200
# 11/11 [==============================] - 6s 555ms/step - loss: 0.6562 - val_loss: 0.6561
# Epoch 73/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6556 - val_loss: 0.6556
# Epoch 74/200
# 11/11 [==============================] - 6s 554ms/step - loss: 0.6550 - val_loss: 0.6551
# Epoch 75/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6546 - val_loss: 0.6546
# Epoch 76/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6542 - val_loss: 0.6541
# Epoch 77/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6533 - val_loss: 0.6536
# Epoch 78/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6532 - val_loss: 0.6531
# Epoch 79/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6527 - val_loss: 0.6526
# Epoch 80/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6523 - val_loss: 0.6521
# Epoch 81/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6518 - val_loss: 0.6517
# Epoch 82/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6512 - val_loss: 0.6512
# Epoch 83/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6507 - val_loss: 0.6507
# Epoch 84/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6501 - val_loss: 0.6502
# Epoch 85/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6496 - val_loss: 0.6497
# Epoch 86/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6491 - val_loss: 0.6492
# Epoch 87/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6485 - val_loss: 0.6487
# Epoch 88/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6480 - val_loss: 0.6482
# Epoch 89/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6475 - val_loss: 0.6477
# Epoch 90/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6471 - val_loss: 0.6472
# Epoch 91/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6470 - val_loss: 0.6467
# Epoch 92/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6461 - val_loss: 0.6462
# Epoch 93/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6455 - val_loss: 0.6457
# Epoch 94/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6451 - val_loss: 0.6452
# Epoch 95/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6450 - val_loss: 0.6447
# Epoch 96/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6439 - val_loss: 0.6443
# Epoch 97/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6439 - val_loss: 0.6438
# Epoch 98/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6433 - val_loss: 0.6433
# Epoch 99/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6431 - val_loss: 0.6428
# Epoch 100/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6428 - val_loss: 0.6423
# Epoch 101/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6417 - val_loss: 0.6418
# Epoch 102/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6416 - val_loss: 0.6413
# Epoch 103/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6407 - val_loss: 0.6409
# Epoch 104/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6405 - val_loss: 0.6404
# Epoch 105/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6396 - val_loss: 0.6399
# Epoch 106/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6391 - val_loss: 0.6394
# Epoch 107/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6392 - val_loss: 0.6389
# Epoch 108/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6384 - val_loss: 0.6384
# Epoch 109/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6380 - val_loss: 0.6379
# Epoch 110/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6373 - val_loss: 0.6375
# Epoch 111/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6367 - val_loss: 0.6370
# Epoch 112/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6365 - val_loss: 0.6365
# Epoch 113/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6357 - val_loss: 0.6360
# Epoch 114/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6354 - val_loss: 0.6355
# Epoch 115/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6347 - val_loss: 0.6350
# Epoch 116/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6344 - val_loss: 0.6346
# Epoch 117/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6343 - val_loss: 0.6341
# Epoch 118/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6332 - val_loss: 0.6336
# Epoch 119/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6329 - val_loss: 0.6331
# Epoch 120/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6326 - val_loss: 0.6326
# Epoch 121/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6320 - val_loss: 0.6321
# Epoch 122/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6315 - val_loss: 0.6317
# Epoch 123/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6311 - val_loss: 0.6312
# Epoch 124/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6304 - val_loss: 0.6307
# Epoch 125/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6302 - val_loss: 0.6302
# Epoch 126/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6297 - val_loss: 0.6298
# Epoch 127/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6288 - val_loss: 0.6293
# Epoch 128/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6286 - val_loss: 0.6288
# Epoch 129/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6280 - val_loss: 0.6283
# Epoch 130/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6277 - val_loss: 0.6278
# Epoch 131/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6272 - val_loss: 0.6274
# Epoch 132/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6267 - val_loss: 0.6269
# Epoch 133/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6263 - val_loss: 0.6264
# Epoch 134/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6255 - val_loss: 0.6259
# Epoch 135/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6255 - val_loss: 0.6255
# Epoch 136/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6251 - val_loss: 0.6250
# Epoch 137/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6241 - val_loss: 0.6245
# Epoch 138/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6241 - val_loss: 0.6240
# Epoch 139/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6235 - val_loss: 0.6236
# Epoch 140/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6225 - val_loss: 0.6231
# Epoch 141/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6225 - val_loss: 0.6226
# Epoch 142/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6220 - val_loss: 0.6221
# Epoch 143/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6218 - val_loss: 0.6217
# Epoch 144/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6215 - val_loss: 0.6212
# Epoch 145/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6207 - val_loss: 0.6207
# Epoch 146/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6198 - val_loss: 0.6203
# Epoch 147/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6192 - val_loss: 0.6198
# Epoch 148/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6192 - val_loss: 0.6193
# Epoch 149/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6183 - val_loss: 0.6188
# Epoch 150/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6185 - val_loss: 0.6184
# Epoch 151/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6175 - val_loss: 0.6179
# Epoch 152/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6172 - val_loss: 0.6174
# Epoch 153/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6165 - val_loss: 0.6170
# Epoch 154/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6164 - val_loss: 0.6165
# Epoch 155/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6155 - val_loss: 0.6160
# Epoch 156/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6158 - val_loss: 0.6156
# Epoch 157/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6145 - val_loss: 0.6151
# Epoch 158/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6149 - val_loss: 0.6146
# Epoch 159/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6140 - val_loss: 0.6142
# Epoch 160/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6130 - val_loss: 0.6137
# Epoch 161/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6125 - val_loss: 0.6132
# Epoch 162/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6128 - val_loss: 0.6128
# Epoch 163/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6110 - val_loss: 0.6123
# Epoch 164/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6119 - val_loss: 0.6118
# Epoch 165/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6109 - val_loss: 0.6114
# Epoch 166/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6103 - val_loss: 0.6109
# Epoch 167/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6097 - val_loss: 0.6104
# Epoch 168/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6096 - val_loss: 0.6100
# Epoch 169/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6092 - val_loss: 0.6095
# Epoch 170/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6089 - val_loss: 0.6090
# Epoch 171/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6080 - val_loss: 0.6086
# Epoch 172/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6080 - val_loss: 0.6081
# Epoch 173/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6068 - val_loss: 0.6077
# Epoch 174/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6065 - val_loss: 0.6072
# Epoch 175/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6067 - val_loss: 0.6067
# Epoch 176/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6061 - val_loss: 0.6063
# Epoch 177/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6051 - val_loss: 0.6058
# Epoch 178/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.6051 - val_loss: 0.6053
# Epoch 179/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6046 - val_loss: 0.6049
# Epoch 180/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6040 - val_loss: 0.6044
# Epoch 181/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6042 - val_loss: 0.6040
# Epoch 182/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6031 - val_loss: 0.6035
# Epoch 183/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6026 - val_loss: 0.6031
# Epoch 184/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6024 - val_loss: 0.6026
# Epoch 185/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6019 - val_loss: 0.6021
# Epoch 186/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.6010 - val_loss: 0.6017
# Epoch 187/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.6006 - val_loss: 0.6012
# Epoch 188/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.6005 - val_loss: 0.6008
# Epoch 189/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.5994 - val_loss: 0.6003
# Epoch 190/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.5994 - val_loss: 0.5998
# Epoch 191/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.5995 - val_loss: 0.5994
# Epoch 192/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.5986 - val_loss: 0.5989
# Epoch 193/200
# 11/11 [==============================] - 6s 550ms/step - loss: 0.5985 - val_loss: 0.5985
# Epoch 194/200
# 11/11 [==============================] - 6s 551ms/step - loss: 0.5972 - val_loss: 0.5980
# Epoch 195/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.5961 - val_loss: 0.5976
# Epoch 196/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.5970 - val_loss: 0.5971
# Epoch 197/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.5956 - val_loss: 0.5967
# Epoch 198/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.5950 - val_loss: 0.5962
# Epoch 199/200
# 11/11 [==============================] - 6s 552ms/step - loss: 0.5956 - val_loss: 0.5958
# Epoch 200/200
# 11/11 [==============================] - 6s 553ms/step - loss: 0.5954 - val_loss: 0.5953

# %% [markdown]
# # 학습한 모델로 돌린 결과는,
# # GD4.gd08.2-4.experiments 화일들을 참고하시기 바랍니다.

# %% [markdown]
# * **GD4.gd08.2-4.experiments_LMS_ready.ipynb**
#
#
#     LMS에서 기본으로 제공한 h5 화일을 사용했을 때의 결과입니다.
#
#     [h5화일 경로]
#     ~/aiffel/aiffel/semantic_segmentation/data/training/seg_model_unet.h5

# %% [markdown]
# * **GD4.gd08.2-5.experiments_UNet_epochs100.ipynb**
#
#   LMS에서 예제소스를 epochs=100 으로 돌린 모델의 결과입니다.

# %% [markdown]
# * **GD4.gd08.2-5.experiments_UNet_epochs200.ipynb**
#
#     LMS에서 예제소스를 epochs=200 으로 돌린 모델의 결과입니다.
#
#     생성된 h5 화일은 epochs=100 으로 돌렸을 때와 동일한 373MB 였으며,<br>
#     결과 역시 epochs=100 으로 돌린 것과 동일하였습니다.
