# %% [markdown]
# <a href="https://colab.research.google.com/github/aivrm/ai/blob/main/GD_2_%EC%97%86%EB%8B%A4%EB%A9%B4_%EC%96%B4%EB%96%BB%EA%B2%8C_%EB%90%A0%EA%B9%8C%3F_(ResNet_Ablation_Study).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip show tensorflow-datasets
# Out:
# Name: tensorflow-datasets
# Version: 4.6.0
# Summary: tensorflow/datasets is a library of datasets ready to use with TensorFlow.
# Home-page: https://github.com/tensorflow/datasets
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: tqdm, etils, numpy, tensorflow-metadata, importlib-resources, typing-extensions, dill, six, requests, promise, absl-py, termcolor, protobuf, toml
# Required-by:

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_test, ds_train), ds_info = tfds.load(   name='cats_vs_dogs',
                                            #split=('train', 'test'),
                                            #split=('train[:35%]', 'train[20%:]'),
                                            #split=('train[:80%]', 'train[80%:]'),
                                            split=('train[:10%]', 'train[10%:20%]'),
                                            as_supervised=True,
                                            shuffle_files=True,
                                            with_info=True,
                                        )

# %%
# Tensorflow 데이터셋을 로드하면 꼭 feature 정보를 확인해 보세요. 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %%
# 데이터의 개수도 확인해 봅시다. 
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(2326, shape=(), dtype=int64)
# tf.Tensor(2326, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, [224, 224])  # 사이즈 조절
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
ds_info.features["label"].num_classes
# Out:
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
# function for building ResNet Block

def build_resnet_block(input_layer,
                       num_cnn=3,
                       channel=64,
                       block_num=1,
                       is_50 = False,
                       is_plain = False
                      ):
    # 입력 레이어
    x = input_layer

    if not is_50:

        # CNN 레이어
        for cnn_num in range(num_cnn):
            identity = x
            x = keras.layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}'
            )(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Conv2D(filters=channel,
                                    kernel_size=(3,3),
                                    activation='relu',
                                    kernel_initializer='he_normal',
                                    padding='same',
                                    name=f'block{block_num}_1_conv{cnn_num}'
            )(x)

            if not is_plain:
                identity_channel = identity.shape.as_list()[-1]

                if identity_channel != channel:
                    identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)
                # skip connection
                x = keras.layers.Add()([x,identity])
            else:
                pass

    else:

        identity = x
        x = keras.layers.Conv2D(filters=channel,
                                kernel_size=(1,1),
                                activation='relu',
                                kernel_initializer='he_normal',
                                padding='same',
                                name=f'block{block_num}_conv{cnn_num}'
        )(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Conv2D(filters=channel,
                                kernel_size=(3,3),
                                activation='relu',
                                kernel_initializer='he_normal',
                                padding='same',
                                name=f'block{block_num}_1_conv{cnn_num}'
        )(x)
        x = keras.layers.Conv2D(filters=channel * 4,
                                kernel_size=(1,1),
                                activation='relu',
                                kernel_initializer='he_normal',
                                padding='same',
                                name=f'block{block_num}_conv{cnn_num}'
        )(x)

        if not is_plain:
            identity_channel = identity.shape.as_list()[-1]

            if identity_channel != channel:
                identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)
            # skip connection
            x = keras.layers.Add()([x,identity])
        else:
            pass

        # Max Pooling 레이어
        # 마지막 블록 뒤에는 pooling을 하지 않음
        if identity.shape[1] != 1:
            x = keras.layers.MaxPooling2D(
                pool_size=(2, 2),
                strides=2,
                name=f'block{block_num}_pooling'
            )(x)

    return x

# %%
resnet_input_layer = keras.layers.Input(shape=(224,224,3))   # 입력 레이어 생성
resnet_block_output = build_resnet_block(resnet_input_layer)  # ResNet 블록 생성

# %%
# 블록 1개짜리 model 생성
model = keras.Model(inputs=resnet_input_layer, outputs=resnet_block_output)  

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv0 (Conv2D)          (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 64  256        ['block1_conv0[0][0]']
#  alization)                     )
#
#  block1_1_conv0 (Conv2D)        (None, 224, 224, 64  36928       ['batch_normalization[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 224, 224, 64  256         ['input_1[0][0]']
#                                 )
#
#  add (Add)                      (None, 224, 224, 64  0           ['block1_1_conv0[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 224, 224, 64  36928       ['add[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 64  256        ['block1_conv1[0][0]']
#  rmalization)                   )
#
#  block1_1_conv1 (Conv2D)        (None, 224, 224, 64  36928       ['batch_normalization_1[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 224, 224, 64  0           ['block1_1_conv1[0][0]',
#                                 )                                 'add[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 224, 224, 64  36928       ['add_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 224, 224, 64  256        ['block1_conv2[0][0]']
#  rmalization)                   )
#
#  block1_1_conv2 (Conv2D)        (None, 224, 224, 64  36928       ['batch_normalization_2[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 224, 224, 64  0           ['block1_1_conv2[0][0]',
#                                 )                                 'add_1[0][0]']
#
# ==================================================================================================
# Total params: 187,456
# Trainable params: 187,072
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
# ResNet 모델 자체를 생성하는 함수입니다.
def build_resnet(input_shape=(224,224,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=10,
                 is_50 = False,
                 is_plain = False
                ):
    
    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.

    if is_50:
        num_cnn_list = [3,4,6,3]
        channel_list = [64,128,256,512]
        num_classes = 10
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer

    # conv1층
    output = keras.layers.Conv2D(filters=64,
                                 kernel_size = (7,7),
                                 strides = 2,
                                 padding = 'valid')(output)
    output = keras.layers.BatchNormalization()(output)

    # conmv2_x pooling
    output = keras.layers.MaxPooling2D(pool_size = (3,3),
                                       strides = 2,)(output)

    # config list들의 길이만큼 반복해서 블록을 생성합니다.
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_resnet_block(
            output,
            num_cnn=num_cnn, 
            channel=channel,
            block_num=i
        )
        
    output = keras.layers.AveragePooling2D(padding = 'same')(output)
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(512, activation='relu', name='fc1')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
# 기본값을 그대로 사용해서 ResNet 모델을 만들면 ResNet-34가 됩니다.
#resnet_34 = build_resnet(is_50 = False)
resnet_34 = build_resnet(input_shape=(224, 224, 3), is_50=False)

resnet_34.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 64  9472        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 109, 109, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['batch_normalization_3[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 54, 54, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 54, 54, 64)  256         ['block0_conv0[0][0]']
#  rmalization)
#
#  block0_1_conv0 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_4[0][0]']
#
#  add_3 (Add)                    (None, 54, 54, 64)   0           ['block0_1_conv0[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  block0_conv1 (Conv2D)          (None, 54, 54, 64)   36928       ['add_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 54, 54, 64)  256         ['block0_conv1[0][0]']
#  rmalization)
#
#  block0_1_conv1 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_5[0][0]']
#
#  add_4 (Add)                    (None, 54, 54, 64)   0           ['block0_1_conv1[0][0]',
#                                                                   'add_3[0][0]']
#
#  block0_conv2 (Conv2D)          (None, 54, 54, 64)   36928       ['add_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 54, 54, 64)  256         ['block0_conv2[0][0]']
#  rmalization)
#
#  block0_1_conv2 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_6[0][0]']
#
#  add_5 (Add)                    (None, 54, 54, 64)   0           ['block0_1_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 54, 54, 128)  73856       ['add_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 54, 54, 128)  512        ['block1_conv0[0][0]']
#  rmalization)
#
#  block1_1_conv0 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_7[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 54, 54, 128)  8320        ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 54, 54, 128)  0           ['block1_1_conv0[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 54, 54, 128)  147584      ['add_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 54, 54, 128)  512        ['block1_conv1[0][0]']
#  rmalization)
#
#  block1_1_conv1 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_8[0][0]']
#
#  add_7 (Add)                    (None, 54, 54, 128)  0           ['block1_1_conv1[0][0]',
#                                                                   'add_6[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 54, 54, 128)  147584      ['add_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 54, 54, 128)  512        ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_1_conv2 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_9[0][0]']
#
#  add_8 (Add)                    (None, 54, 54, 128)  0           ['block1_1_conv2[0][0]',
#                                                                   'add_7[0][0]']
#
#  block1_conv3 (Conv2D)          (None, 54, 54, 128)  147584      ['add_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 54, 54, 128)  512        ['block1_conv3[0][0]']
#  ormalization)
#
#  block1_1_conv3 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_10[0][0]']
#
#  add_9 (Add)                    (None, 54, 54, 128)  0           ['block1_1_conv3[0][0]',
#                                                                   'add_8[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 54, 54, 256)  295168      ['add_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv0[0][0]']
#  ormalization)
#
#  block2_1_conv0 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_11[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 54, 54, 256)  33024       ['add_9[0][0]']
#
#  add_10 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv0[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 54, 54, 256)  590080      ['add_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_1_conv1 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_12[0][0]']
#
#  add_11 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv1[0][0]',
#                                                                   'add_10[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 54, 54, 256)  590080      ['add_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_1_conv2 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_13[0][0]']
#
#  add_12 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv2[0][0]',
#                                                                   'add_11[0][0]']
#
#  block2_conv3 (Conv2D)          (None, 54, 54, 256)  590080      ['add_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv3[0][0]']
#  ormalization)
#
#  block2_1_conv3 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_14[0][0]']
#
#  add_13 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv3[0][0]',
#                                                                   'add_12[0][0]']
#
#  block2_conv4 (Conv2D)          (None, 54, 54, 256)  590080      ['add_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv4[0][0]']
#  ormalization)
#
#  block2_1_conv4 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_15[0][0]']
#
#  add_14 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv4[0][0]',
#                                                                   'add_13[0][0]']
#
#  block2_conv5 (Conv2D)          (None, 54, 54, 256)  590080      ['add_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv5[0][0]']
#  ormalization)
#
#  block2_1_conv5 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_16[0][0]']
#
#  add_15 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv5[0][0]',
#                                                                   'add_14[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 54, 54, 512)  1180160     ['add_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv0[0][0]']
#  ormalization)
#
#  block3_1_conv0 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_17[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 54, 54, 512)  131584      ['add_15[0][0]']
#
#  add_16 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv0[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_16[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_1_conv1 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_18[0][0]']
#
#  add_17 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv1[0][0]',
#                                                                   'add_16[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_17[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_1_conv2 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_19[0][0]']
#
#  add_18 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv2[0][0]',
#                                                                   'add_17[0][0]']
#
#  average_pooling2d (AveragePool  (None, 27, 27, 512)  0          ['add_18[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 373248)       0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 512)          191103488   ['flatten[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 212,400,138
# Trainable params: 212,392,458
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
# 기본값을 그대로 사용해서 ResNet 모델을 만들면 ResNet-34가 되지만,
# is_50=True 로 하면, ResNet-50 이 됨.
resnet_50 = build_resnet(input_shape=(224, 224, 3), is_50=True)

resnet_50.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_5 (Conv2D)              (None, 109, 109, 64  9472        ['input_3[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 109, 109, 64  256        ['conv2d_5[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)  0           ['batch_normalization_20[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 54, 54, 64)   36928       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 54, 54, 64)  256         ['block0_conv0[0][0]']
#  ormalization)
#
#  block0_1_conv0 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_21[0][0]']
#
#  add_19 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv0[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  block0_conv1 (Conv2D)          (None, 54, 54, 64)   36928       ['add_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 54, 54, 64)  256         ['block0_conv1[0][0]']
#  ormalization)
#
#  block0_1_conv1 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_22[0][0]']
#
#  add_20 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv1[0][0]',
#                                                                   'add_19[0][0]']
#
#  block0_conv2 (Conv2D)          (None, 54, 54, 64)   36928       ['add_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 54, 54, 64)  256         ['block0_conv2[0][0]']
#  ormalization)
#
#  block0_1_conv2 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_23[0][0]']
#
#  add_21 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv2[0][0]',
#                                                                   'add_20[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 54, 54, 128)  73856       ['add_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 54, 54, 128)  512        ['block1_conv0[0][0]']
#  ormalization)
#
#  block1_1_conv0 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_24[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 54, 54, 128)  8320        ['add_21[0][0]']
#
#  add_22 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv0[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 54, 54, 128)  147584      ['add_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 54, 54, 128)  512        ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_1_conv1 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_25[0][0]']
#
#  add_23 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv1[0][0]',
#                                                                   'add_22[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 54, 54, 128)  147584      ['add_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 54, 54, 128)  512        ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_1_conv2 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_26[0][0]']
#
#  add_24 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv2[0][0]',
#                                                                   'add_23[0][0]']
#
#  block1_conv3 (Conv2D)          (None, 54, 54, 128)  147584      ['add_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 54, 54, 128)  512        ['block1_conv3[0][0]']
#  ormalization)
#
#  block1_1_conv3 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_27[0][0]']
#
#  add_25 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv3[0][0]',
#                                                                   'add_24[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 54, 54, 256)  295168      ['add_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv0[0][0]']
#  ormalization)
#
#  block2_1_conv0 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_28[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 54, 54, 256)  33024       ['add_25[0][0]']
#
#  add_26 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv0[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 54, 54, 256)  590080      ['add_26[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_1_conv1 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_29[0][0]']
#
#  add_27 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv1[0][0]',
#                                                                   'add_26[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 54, 54, 256)  590080      ['add_27[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_1_conv2 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_30[0][0]']
#
#  add_28 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv2[0][0]',
#                                                                   'add_27[0][0]']
#
#  block2_conv3 (Conv2D)          (None, 54, 54, 256)  590080      ['add_28[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv3[0][0]']
#  ormalization)
#
#  block2_1_conv3 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_31[0][0]']
#
#  add_29 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv3[0][0]',
#                                                                   'add_28[0][0]']
#
#  block2_conv4 (Conv2D)          (None, 54, 54, 256)  590080      ['add_29[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv4[0][0]']
#  ormalization)
#
#  block2_1_conv4 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_32[0][0]']
#
#  add_30 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv4[0][0]',
#                                                                   'add_29[0][0]']
#
#  block2_conv5 (Conv2D)          (None, 54, 54, 256)  590080      ['add_30[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv5[0][0]']
#  ormalization)
#
#  block2_1_conv5 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_33[0][0]']
#
#  add_31 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv5[0][0]',
#                                                                   'add_30[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 54, 54, 512)  1180160     ['add_31[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv0[0][0]']
#  ormalization)
#
#  block3_1_conv0 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_34[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 54, 54, 512)  131584      ['add_31[0][0]']
#
#  add_32 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv0[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_32[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_1_conv1 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_35[0][0]']
#
#  add_33 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv1[0][0]',
#                                                                   'add_32[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_33[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_1_conv2 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_36[0][0]']
#
#  add_34 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv2[0][0]',
#                                                                   'add_33[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 27, 27, 512)  0          ['add_34[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 373248)       0           ['average_pooling2d_1[0][0]']
#
#  fc1 (Dense)                    (None, 512)          191103488   ['flatten[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 212,400,138
# Trainable params: 212,392,458
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
# 원하는 블록의 설계에 따라 매개변수로 리스트를 전달해 줍니다.
resnet_50 = build_resnet(
    num_cnn_list=[2,2,4,4,4],
    channel_list=[64,128,256,512,512],
    is_50=True
)

resnet_50.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_9 (Conv2D)              (None, 109, 109, 64  9472        ['input_4[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 109, 109, 64  256        ['conv2d_9[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 54, 54, 64)  0           ['batch_normalization_37[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 54, 54, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 54, 54, 64)  256         ['block0_conv0[0][0]']
#  ormalization)
#
#  block0_1_conv0 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_38[0][0]']
#
#  add_35 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv0[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  block0_conv1 (Conv2D)          (None, 54, 54, 64)   36928       ['add_35[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 54, 54, 64)  256         ['block0_conv1[0][0]']
#  ormalization)
#
#  block0_1_conv1 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_39[0][0]']
#
#  add_36 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv1[0][0]',
#                                                                   'add_35[0][0]']
#
#  block0_conv2 (Conv2D)          (None, 54, 54, 64)   36928       ['add_36[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 54, 54, 64)  256         ['block0_conv2[0][0]']
#  ormalization)
#
#  block0_1_conv2 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_40[0][0]']
#
#  add_37 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv2[0][0]',
#                                                                   'add_36[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 54, 54, 128)  73856       ['add_37[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 54, 54, 128)  512        ['block1_conv0[0][0]']
#  ormalization)
#
#  block1_1_conv0 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_41[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 54, 54, 128)  8320        ['add_37[0][0]']
#
#  add_38 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv0[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 54, 54, 128)  147584      ['add_38[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 54, 54, 128)  512        ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_1_conv1 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_42[0][0]']
#
#  add_39 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv1[0][0]',
#                                                                   'add_38[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 54, 54, 128)  147584      ['add_39[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 54, 54, 128)  512        ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_1_conv2 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_43[0][0]']
#
#  add_40 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv2[0][0]',
#                                                                   'add_39[0][0]']
#
#  block1_conv3 (Conv2D)          (None, 54, 54, 128)  147584      ['add_40[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 54, 54, 128)  512        ['block1_conv3[0][0]']
#  ormalization)
#
#  block1_1_conv3 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_44[0][0]']
#
#  add_41 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv3[0][0]',
#                                                                   'add_40[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 54, 54, 256)  295168      ['add_41[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv0[0][0]']
#  ormalization)
#
#  block2_1_conv0 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_45[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 54, 54, 256)  33024       ['add_41[0][0]']
#
#  add_42 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv0[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 54, 54, 256)  590080      ['add_42[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_1_conv1 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_46[0][0]']
#
#  add_43 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv1[0][0]',
#                                                                   'add_42[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 54, 54, 256)  590080      ['add_43[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_1_conv2 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_47[0][0]']
#
#  add_44 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv2[0][0]',
#                                                                   'add_43[0][0]']
#
#  block2_conv3 (Conv2D)          (None, 54, 54, 256)  590080      ['add_44[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv3[0][0]']
#  ormalization)
#
#  block2_1_conv3 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_48[0][0]']
#
#  add_45 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv3[0][0]',
#                                                                   'add_44[0][0]']
#
#  block2_conv4 (Conv2D)          (None, 54, 54, 256)  590080      ['add_45[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv4[0][0]']
#  ormalization)
#
#  block2_1_conv4 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_49[0][0]']
#
#  add_46 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv4[0][0]',
#                                                                   'add_45[0][0]']
#
#  block2_conv5 (Conv2D)          (None, 54, 54, 256)  590080      ['add_46[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv5[0][0]']
#  ormalization)
#
#  block2_1_conv5 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_50[0][0]']
#
#  add_47 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv5[0][0]',
#                                                                   'add_46[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 54, 54, 512)  1180160     ['add_47[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv0[0][0]']
#  ormalization)
#
#  block3_1_conv0 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_51[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 54, 54, 512)  131584      ['add_47[0][0]']
#
#  add_48 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv0[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_48[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_1_conv1 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_52[0][0]']
#
#  add_49 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv1[0][0]',
#                                                                   'add_48[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_49[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_1_conv2 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_53[0][0]']
#
#  add_50 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv2[0][0]',
#                                                                   'add_49[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 27, 27, 512)  0          ['add_50[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 373248)       0           ['average_pooling2d_2[0][0]']
#
#  fc1 (Dense)                    (None, 512)          191103488   ['flatten[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 212,400,138
# Trainable params: 212,392,458
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
# skip connection 이 없는 일반 네트워크(plain net)
def build_plainnet(input_shape=(224,224,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=10,
                 is_50 = False,
                 is_plain = False
                ):
    
    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.

    if is_50:
        num_cnn_list = [3,4,6,3]
        channel_list = [64,128,256,512]
        num_classes = 10
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer

    # conv1층
    output = keras.layers.Conv2D(filters=64,
                                 kernel_size = (7,7),
                                 strides = 2,
                                 padding = 'valid')(output)
    output = keras.layers.BatchNormalization()(output)

    # conmv2_x pooling
    output = keras.layers.MaxPooling2D(pool_size = (3,3),
                                       strides = 2,
    )(output)

    # config list들의 길이만큼 반복해서 블록을 생성합니다.
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_resnet_block(
            output,
            num_cnn=num_cnn, 
            channel=channel,
            block_num=i,
            is_plain = True  # 333
        )
        
    output = keras.layers.AveragePooling2D(padding = 'same')(output)
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(512, activation='relu', name='fc1')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
# skip connection이 없는 PlainNet-34
plainnet_34 = build_resnet(input_shape=(224, 224, 3), is_50=False)

plainnet_34.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_13 (Conv2D)             (None, 109, 109, 64  9472        ['input_5[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 109, 109, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 54, 54, 64)  0           ['batch_normalization_54[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 54, 54, 64)   36928       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 54, 54, 64)  256         ['block0_conv0[0][0]']
#  ormalization)
#
#  block0_1_conv0 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_55[0][0]']
#
#  add_51 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv0[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  block0_conv1 (Conv2D)          (None, 54, 54, 64)   36928       ['add_51[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 54, 54, 64)  256         ['block0_conv1[0][0]']
#  ormalization)
#
#  block0_1_conv1 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_56[0][0]']
#
#  add_52 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv1[0][0]',
#                                                                   'add_51[0][0]']
#
#  block0_conv2 (Conv2D)          (None, 54, 54, 64)   36928       ['add_52[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 54, 54, 64)  256         ['block0_conv2[0][0]']
#  ormalization)
#
#  block0_1_conv2 (Conv2D)        (None, 54, 54, 64)   36928       ['batch_normalization_57[0][0]']
#
#  add_53 (Add)                   (None, 54, 54, 64)   0           ['block0_1_conv2[0][0]',
#                                                                   'add_52[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 54, 54, 128)  73856       ['add_53[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 54, 54, 128)  512        ['block1_conv0[0][0]']
#  ormalization)
#
#  block1_1_conv0 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_58[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 54, 54, 128)  8320        ['add_53[0][0]']
#
#  add_54 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv0[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 54, 54, 128)  147584      ['add_54[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 54, 54, 128)  512        ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_1_conv1 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_59[0][0]']
#
#  add_55 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv1[0][0]',
#                                                                   'add_54[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 54, 54, 128)  147584      ['add_55[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 54, 54, 128)  512        ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_1_conv2 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_60[0][0]']
#
#  add_56 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv2[0][0]',
#                                                                   'add_55[0][0]']
#
#  block1_conv3 (Conv2D)          (None, 54, 54, 128)  147584      ['add_56[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 54, 54, 128)  512        ['block1_conv3[0][0]']
#  ormalization)
#
#  block1_1_conv3 (Conv2D)        (None, 54, 54, 128)  147584      ['batch_normalization_61[0][0]']
#
#  add_57 (Add)                   (None, 54, 54, 128)  0           ['block1_1_conv3[0][0]',
#                                                                   'add_56[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 54, 54, 256)  295168      ['add_57[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv0[0][0]']
#  ormalization)
#
#  block2_1_conv0 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_62[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 54, 54, 256)  33024       ['add_57[0][0]']
#
#  add_58 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv0[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 54, 54, 256)  590080      ['add_58[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_1_conv1 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_63[0][0]']
#
#  add_59 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv1[0][0]',
#                                                                   'add_58[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 54, 54, 256)  590080      ['add_59[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_1_conv2 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_64[0][0]']
#
#  add_60 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv2[0][0]',
#                                                                   'add_59[0][0]']
#
#  block2_conv3 (Conv2D)          (None, 54, 54, 256)  590080      ['add_60[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv3[0][0]']
#  ormalization)
#
#  block2_1_conv3 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_65[0][0]']
#
#  add_61 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv3[0][0]',
#                                                                   'add_60[0][0]']
#
#  block2_conv4 (Conv2D)          (None, 54, 54, 256)  590080      ['add_61[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv4[0][0]']
#  ormalization)
#
#  block2_1_conv4 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_66[0][0]']
#
#  add_62 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv4[0][0]',
#                                                                   'add_61[0][0]']
#
#  block2_conv5 (Conv2D)          (None, 54, 54, 256)  590080      ['add_62[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 54, 54, 256)  1024       ['block2_conv5[0][0]']
#  ormalization)
#
#  block2_1_conv5 (Conv2D)        (None, 54, 54, 256)  590080      ['batch_normalization_67[0][0]']
#
#  add_63 (Add)                   (None, 54, 54, 256)  0           ['block2_1_conv5[0][0]',
#                                                                   'add_62[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 54, 54, 512)  1180160     ['add_63[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv0[0][0]']
#  ormalization)
#
#  block3_1_conv0 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_68[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 54, 54, 512)  131584      ['add_63[0][0]']
#
#  add_64 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv0[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_64[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_1_conv1 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_69[0][0]']
#
#  add_65 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv1[0][0]',
#                                                                   'add_64[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 54, 54, 512)  2359808     ['add_65[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 54, 54, 512)  2048       ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_1_conv2 (Conv2D)        (None, 54, 54, 512)  2359808     ['batch_normalization_70[0][0]']
#
#  add_66 (Add)                   (None, 54, 54, 512)  0           ['block3_1_conv2[0][0]',
#                                                                   'add_65[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 27, 27, 512)  0          ['add_66[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 373248)       0           ['average_pooling2d_3[0][0]']
#
#  fc1 (Dense)                    (None, 512)          191103488   ['flatten[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 212,400,138
# Trainable params: 212,392,458
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
# skip connection이 없는 PlainNet-50
plainnet_50 = build_plainnet(input_shape=(224, 224, 3), is_50=True)

plainnet_50.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_17 (Conv2D)          (None, 109, 109, 64)      9472
#
#  batch_normalization_71 (Bat  (None, 109, 109, 64)     256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  block0_conv0 (Conv2D)       (None, 54, 54, 64)        36928
#
#  batch_normalization_72 (Bat  (None, 54, 54, 64)       256
#  chNormalization)
#
#  block0_1_conv0 (Conv2D)     (None, 54, 54, 64)        36928
#
#  block0_conv1 (Conv2D)       (None, 54, 54, 64)        36928
#
#  batch_normalization_73 (Bat  (None, 54, 54, 64)       256
#  chNormalization)
#
#  block0_1_conv1 (Conv2D)     (None, 54, 54, 64)        36928
#
#  block0_conv2 (Conv2D)       (None, 54, 54, 64)        36928
#
#  batch_normalization_74 (Bat  (None, 54, 54, 64)       256
#  chNormalization)
#
#  block0_1_conv2 (Conv2D)     (None, 54, 54, 64)        36928
#
#  block1_conv0 (Conv2D)       (None, 54, 54, 128)       73856
#
#  batch_normalization_75 (Bat  (None, 54, 54, 128)      512
#  chNormalization)
#
#  block1_1_conv0 (Conv2D)     (None, 54, 54, 128)       147584
#
#  block1_conv1 (Conv2D)       (None, 54, 54, 128)       147584
#
#  batch_normalization_76 (Bat  (None, 54, 54, 128)      512
#  chNormalization)
#
#  block1_1_conv1 (Conv2D)     (None, 54, 54, 128)       147584
#
#  block1_conv2 (Conv2D)       (None, 54, 54, 128)       147584
#
#  batch_normalization_77 (Bat  (None, 54, 54, 128)      512
#  chNormalization)
#
#  block1_1_conv2 (Conv2D)     (None, 54, 54, 128)       147584
#
#  block1_conv3 (Conv2D)       (None, 54, 54, 128)       147584
#
#  batch_normalization_78 (Bat  (None, 54, 54, 128)      512
#  chNormalization)
#
#  block1_1_conv3 (Conv2D)     (None, 54, 54, 128)       147584
#
#  block2_conv0 (Conv2D)       (None, 54, 54, 256)       295168
#
#  batch_normalization_79 (Bat  (None, 54, 54, 256)      1024
#  chNormalization)
#
#  block2_1_conv0 (Conv2D)     (None, 54, 54, 256)       590080
#
#  block2_conv1 (Conv2D)       (None, 54, 54, 256)       590080
#
#  batch_normalization_80 (Bat  (None, 54, 54, 256)      1024
#  chNormalization)
#
#  block2_1_conv1 (Conv2D)     (None, 54, 54, 256)       590080
#
#  block2_conv2 (Conv2D)       (None, 54, 54, 256)       590080
#
#  batch_normalization_81 (Bat  (None, 54, 54, 256)      1024
#  chNormalization)
#
#  block2_1_conv2 (Conv2D)     (None, 54, 54, 256)       590080
#
#  block2_conv3 (Conv2D)       (None, 54, 54, 256)       590080
#
#  batch_normalization_82 (Bat  (None, 54, 54, 256)      1024
#  chNormalization)
#
#  block2_1_conv3 (Conv2D)     (None, 54, 54, 256)       590080
#
#  block2_conv4 (Conv2D)       (None, 54, 54, 256)       590080
#
#  batch_normalization_83 (Bat  (None, 54, 54, 256)      1024
#  chNormalization)
#
#  block2_1_conv4 (Conv2D)     (None, 54, 54, 256)       590080
#
#  block2_conv5 (Conv2D)       (None, 54, 54, 256)       590080
#
#  batch_normalization_84 (Bat  (None, 54, 54, 256)      1024
#  chNormalization)
#
#  block2_1_conv5 (Conv2D)     (None, 54, 54, 256)       590080
#
#  block3_conv0 (Conv2D)       (None, 54, 54, 512)       1180160
#
#  batch_normalization_85 (Bat  (None, 54, 54, 512)      2048
#  chNormalization)
#
#  block3_1_conv0 (Conv2D)     (None, 54, 54, 512)       2359808
#
#  block3_conv1 (Conv2D)       (None, 54, 54, 512)       2359808
#
#  batch_normalization_86 (Bat  (None, 54, 54, 512)      2048
#  chNormalization)
#
#  block3_1_conv1 (Conv2D)     (None, 54, 54, 512)       2359808
#
#  block3_conv2 (Conv2D)       (None, 54, 54, 512)       2359808
#
#  batch_normalization_87 (Bat  (None, 54, 54, 512)      2048
#  chNormalization)
#
#  block3_1_conv2 (Conv2D)     (None, 54, 54, 512)       2359808
#
#  average_pooling2d_4 (Averag  (None, 27, 27, 512)      0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 373248)            0
#
#  fc1 (Dense)                 (None, 512)               191103488
#
#  predictions (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 212,227,210
# Trainable params: 212,219,530
# Non-trainable params: 7,680
# _________________________________________________________________

# %%
BATCH_SIZE = 256
EPOCH = 15

# %%
'''
(ds_test, ds_train), ds_info = tfds.load(   name='cats_vs_dogs',
                                            #split=('train', 'test'),
                                            #split=('train[:35%]', 'train[20%:]'),
                                            split=('train[:80%]', 'train[80%:]'),
                                            as_supervised=True,
                                            shuffle_files=True,
                                            with_info=True,
                                        )
'''
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    #optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    #UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_34 = resnet_34.fit(
    ds_train,
    #steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    #validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    steps_per_epoch=int(ds_info.splits['train[:10%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[10%:20%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15

# %%
plainnet_34.compile(
    loss='sparse_categorical_crossentropy',
    #optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    #UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain34 = plainnet_34.fit(
    ds_train,
    #steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    #validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    steps_per_epoch=int(ds_info.splits['train[:10%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[10%:50%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

# %%
plainnet_50.compile(
    loss='sparse_categorical_crossentropy',
    #optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    #UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_plain50 = plainnet_50.fit(
    ds_train,
    #steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    #validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    steps_per_epoch=int(ds_info.splits['train[:10%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[10%:50%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

# %%
resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    # optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    #UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_50 = resnet_50.fit(
    ds_train,
    #steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    #validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    steps_per_epoch=int(ds_info.splits['train[:10%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[10%:50%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

# %%
import matplotlib.pyplot as plt

plt.plot(history_34.history['loss'], 'r')
plt.plot(history_plain34.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'resnet_50'], loc='upper left')
plt.show()

# %%
plt.plot(history_50.history['val_accuracy'], 'r')
plt.plot(history_plain50.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'resnet_50'], loc='upper left')
plt.show()

# %% [markdown]
# ### 회고

# %% [markdown]
# Out of Memory
